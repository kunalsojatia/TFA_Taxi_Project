# %%
import pandas as pd
import requests
import re
from tqdm import tqdm
import time
import os
import glob

# %%
df = pd.read_csv(r"C:\Users\Kunal\Desktop\TFA\data\yellow_tripdata_2009-01.csv")
df.head()
# Out:
#   vendor_name Trip_Pickup_DateTime Trip_Dropoff_DateTime  Passenger_Count  \
# 0         VTS  2009-01-04 02:52:00   2009-01-04 03:02:00                1
# 1         VTS  2009-01-04 03:31:00   2009-01-04 03:38:00                3
# 2         VTS  2009-01-03 15:43:00   2009-01-03 15:57:00                5
# 3         DDS  2009-01-01 20:52:58   2009-01-01 21:14:00                1
# 4         DDS  2009-01-24 16:18:23   2009-01-24 16:24:56                1
#
#    Trip_Distance  Start_Lon  Start_Lat  Rate_Code  store_and_forward  \
# 0           2.63 -73.991957  40.721567        NaN                NaN
# 1           4.55 -73.982102  40.736290        NaN                NaN
# 2          10.35 -74.002587  40.739748        NaN                NaN
# 3           5.00 -73.974267  40.790955        NaN                NaN
# 4           0.40 -74.001580  40.719382        NaN                NaN
#
#      End_Lon    End_Lat Payment_Type  Fare_Amt  surcharge  mta_tax  Tip_Amt  \
# ...

# %%
df2 = pd.read_csv(r"C:\Users\Kunal\Desktop\TFA\data\yellow_tripdata_2015-01.csv")
df2.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2015-01-15 19:05:39   2015-01-15 19:23:42                1
# 1         1  2015-01-10 20:33:38   2015-01-10 20:53:28                1
# 2         1  2015-01-10 20:33:38   2015-01-10 20:43:41                1
# 3         1  2015-01-10 20:33:39   2015-01-10 20:35:31                1
# 4         1  2015-01-10 20:33:39   2015-01-10 20:52:58                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0           1.59        -73.993896        40.750111           1
# 1           3.30        -74.001648        40.724243           1
# 2           1.80        -73.963341        40.802788           1
# 3           0.50        -74.009087        40.713818           1
# 4           3.00        -73.971176        40.762428           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# ...

# %%
len(df.columns)
# Out:
# 18

# %%
len(df2.columns)
# Out:
# 19

# %%
df2copy=df2.drop(columns=["improvement_surcharge"])

# %%
df1copy=df.copy()

# %%
df2copy.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2015-01-15 19:05:39   2015-01-15 19:23:42                1
# 1         1  2015-01-10 20:33:38   2015-01-10 20:53:28                1
# 2         1  2015-01-10 20:33:38   2015-01-10 20:43:41                1
# 3         1  2015-01-10 20:33:39   2015-01-10 20:35:31                1
# 4         1  2015-01-10 20:33:39   2015-01-10 20:52:58                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0           1.59        -73.993896        40.750111           1
# 1           3.30        -74.001648        40.724243           1
# 2           1.80        -73.963341        40.802788           1
# 3           0.50        -74.009087        40.713818           1
# 4           3.00        -73.971176        40.762428           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# ...

# %%
df2copy.rename()

# %%
mapping = {df.columns[0]: 'vendor_name', 
           df.columns[1]: 'Trip_Pickup_DateTime', 
           df.columns[2]: 'Trip_Dropoff_DateTime', 
           df.columns[3]: 'Passenger_Count',
           df.columns[4]:'Trip_Distance', 
           df.columns[5]:'Start_Lon', 
           df.columns[6]:'Start_Lat',
           df.columns[7]:'Rate_Code',
           df.columns[8]:'store_and_forward',
           df.columns[9]:'End_Lon',
           df.columns[10]:'End_Lat',
           df.columns[11]:'Payment_Type',
           df.columns[12]:'Fare_Amt',
           df.columns[13]:'surcharge',
           df.columns[14]:'mta_tax',
           df.columns[15]:'Tip_Amt',
           df.columns[16]:'Tolls_Amt',
           df.columns[17]:'Total_Amt'}

# %%
df2copy.columns=mapping

# %%
df2copy.head()
# Out:
#    vendor_name Trip_Pickup_DateTime Trip_Dropoff_DateTime  Passenger_Count  \
# 0            2  2015-01-15 19:05:39   2015-01-15 19:23:42                1
# 1            1  2015-01-10 20:33:38   2015-01-10 20:53:28                1
# 2            1  2015-01-10 20:33:38   2015-01-10 20:43:41                1
# 3            1  2015-01-10 20:33:39   2015-01-10 20:35:31                1
# 4            1  2015-01-10 20:33:39   2015-01-10 20:52:58                1
#
#    Trip_Distance  Start_Lon  Start_Lat  Rate_Code store_and_forward  \
# 0           1.59 -73.993896  40.750111          1                 N
# 1           3.30 -74.001648  40.724243          1                 N
# 2           1.80 -73.963341  40.802788          1                 N
# 3           0.50 -74.009087  40.713818          1                 N
# 4           3.00 -73.971176  40.762428          1                 N
#
#      End_Lon    End_Lat  Payment_Type  Fare_Amt  surcharge  mta_tax  Tip_Amt  \
# ...

# %%
sampledf=pd.DataFrame()
dftemp=df
subset=df.sample(n=3000)
if len(subset.columns)>18:
    subset=subset.drop(columns=["improvement_surcharge"])
    print("here")
sampledf=sampledf.append(subset)
print(len(sampledf))
sampledf.to_csv("test.csv")
# Out:
# here
# 3000

# %%
dfnew=pd.DataFrame()
dfnew.append(subset)
# Out:
#           VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 7814857          1  2015-01-31 15:26:11   2015-01-31 15:41:31
# 8582862          2  2015-01-09 22:44:10   2015-01-09 22:51:33
# 12717030         1  2015-01-25 15:24:45   2015-01-25 15:36:34
# 9761643          1  2015-01-18 13:54:52   2015-01-18 13:59:13
# 343519           1  2015-01-10 23:48:46   2015-01-11 00:05:16
# ...            ...                  ...                   ...
# 885609           2  2015-01-21 18:29:33   2015-01-21 18:38:26
# 8836877          1  2015-01-15 21:34:45   2015-01-15 21:44:06
# 10683670         1  2015-01-22 07:54:01   2015-01-22 08:03:15
# 3197822          2  2015-01-15 07:13:11   2015-01-15 07:18:01
# 10817814         2  2015-01-27 14:22:45   2015-01-27 14:28:09
#
#           passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# 7814857                 2           2.30        -73.981850        40.770512
# ...

# %%
dfnew
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
dftemp=df2
subset=df.sample(n=3000)
if len(subset.columns)>18:
    subset=subset.drop(columns=["improvement_surcharge"])
    print("here")
sampledf=sampledf.append(subset)
print(len(sampledf))
sampledf.to_csv("test.csv")
# Out:
# here
# 6000

# %%
sampledf.sample(n=5)
# Out:
#           VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 12684820         1  2015-01-05 12:45:31   2015-01-05 12:53:21
# 9480559          1  2015-01-20 07:31:50   2015-01-20 07:44:59
# 6607634          1  2015-01-14 12:59:26   2015-01-14 13:01:03
# 4656193          1  2015-01-11 23:53:23   2015-01-12 00:13:36
# 12625057         2  2015-01-03 21:24:41   2015-01-03 21:40:10
#
#           passenger_count  trip_distance  pickup_longitude  pickup_latitude  \
# 12684820                1           1.30        -73.979538        40.727531
# 9480559                 1           3.80        -73.887581        40.766956
# 6607634                 1           0.30        -73.985832        40.730991
# 4656193                 1           6.80        -73.952087        40.710884
# 12625057                5           2.83        -73.995766        40.736843
#
#           RateCodeID store_and_fwd_flag  dropoff_longitude  dropoff_latitude  \
# ...

# %%
sampledf.to_csv(r"C:\Users\Kunal\Desktop\TFA\sample\subset" +str(i)+ ".csv")

# %%
i=4

# %%
path = "C:\\Users\\Kunal\\Desktop\\TFA\\data"
csv_files = glob.glob(os.path.join(path, "*.csv"))

# %%
csv_files
# Out:
# ['C:\\Users\\Kunal\\Desktop\\TFA\\data\\yellow_tripdata_2009-01.csv',
#  'C:\\Users\\Kunal\\Desktop\\TFA\\data\\yellow_tripdata_2009-02.csv',
#  'C:\\Users\\Kunal\\Desktop\\TFA\\data\\yellow_tripdata_2009-03.csv',
#  'C:\\Users\\Kunal\\Desktop\\TFA\\data\\yellow_tripdata_2009-04.csv',
#  'C:\\Users\\Kunal\\Desktop\\TFA\\data\\yellow_tripdata_2009-05.csv',
#  'C:\\Users\\Kunal\\Desktop\\TFA\\data\\yellow_tripdata_2009-06.csv',
#  'C:\\Users\\Kunal\\Desktop\\TFA\\data\\yellow_tripdata_2009-07.csv',
#  'C:\\Users\\Kunal\\Desktop\\TFA\\data\\yellow_tripdata_2009-08.csv',
#  'C:\\Users\\Kunal\\Desktop\\TFA\\data\\yellow_tripdata_2009-09.csv',
#  'C:\\Users\\Kunal\\Desktop\\TFA\\data\\yellow_tripdata_2009-10.csv',
#  'C:\\Users\\Kunal\\Desktop\\TFA\\data\\yellow_tripdata_2009-11.csv',
#  'C:\\Users\\Kunal\\Desktop\\TFA\\data\\yellow_tripdata_2009-12.csv',
#  'C:\\Users\\Kunal\\Desktop\\TFA\\data\\yellow_tripdata_2010-01.csv',
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16360/3289350417.py in <module>
# ----> 1 df.columns
#
# NameError: name 'df' is not defined

# %%
df2.iloc[1].to_dict()
# Out:
# {'VendorID': 1,
#  'tpep_pickup_datetime': '2015-01-10 20:33:38',
#  'tpep_dropoff_datetime': '2015-01-10 20:53:28',
#  'passenger_count': 1,
#  'trip_distance': 3.3,
#  'pickup_longitude': -74.00164794921875,
#  'pickup_latitude': 40.7242431640625,
#  'RateCodeID': 1,
#  'store_and_fwd_flag': 'N',
#  'dropoff_longitude': -73.99441528320312,
#  'dropoff_latitude': 40.75910949707031,
#  'payment_type': 1,
#  'fare_amount': 14.5,
#  'extra': 0.5,
#  'mta_tax': 0.5,
#  'tip_amount': 2.0,
#  'tolls_amount': 0.0,
#  'improvement_surcharge': 0.3,
#  'total_amount': 17.8}

# %%
df2copysub=df2copy.sample(n=1)

# %%
df2copysub.to_csv("start.csv",index=False)

# %%
from sqlalchemy import create_engine

engine = create_engine(f"sqlite:///f1.db", echo=True)

# %%
import logging
sqllogger = logging.getLogger("sqlalchemy.engine.Engine")
formatter = logging.Formatter("[sqlalchemy] %(message)s")
sqllogger.handlers[0].setFormatter(formatter)

# %%
out=engine.execute(r"select * from persons")
# Out:
# [sqlalchemy] select * from persons
# [sqlalchemy] [raw sql] ()

# %%
out.all()
# Out:
# []
